# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("data.csv")
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.drop("id", axis=1, inplace=True)
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
data['diagnosis'] = data['diagnosis'].replace(['M', 'B'], [0,1])
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
data.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.627417    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      1.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
import seaborn as sns

sns.catplot(data=data, y="radius_mean", x="diagnosis")

## lower mean radius are benign with higher density

# %%
data.groupby("diagnosis")['radius_mean'].describe()

## mean radius of the tumor is a valid indicator
# Out:
#            count       mean       std     min     25%     50%    75%    max
# diagnosis
# 0          212.0  17.462830  3.203971  10.950  15.075  17.325  19.59  28.11
# 1          357.0  12.146524  1.780512   6.981  11.080  12.200  13.37  17.85

# %%
sns.catplot(data=data, y="texture_mean", x="diagnosis")

## looks like the variation is uniform

# %%
data.groupby("diagnosis")['texture_mean'].describe()

## validates hypothesis -  mean texture not a valid indicator

data.drop("texture_mean", axis=1, inplace=True)
data.head()
# Out:
#    diagnosis  radius_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          0        17.99          122.80     1001.0          0.11840
# 1          0        20.57          132.90     1326.0          0.08474
# 2          0        19.69          130.00     1203.0          0.10960
# 3          0        11.42           77.58      386.1          0.14250
# 4          0        20.29          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
sns.catplot(data=data, y="perimeter_mean", x="diagnosis")

## lower perimeter is majorly benign - look at dat density

# %%
data.groupby("diagnosis")['perimeter_mean'].describe()

## 40% difference
# Out:
#            count        mean        std    min     25%     50%      75%    max
# diagnosis
# 0          212.0  115.365377  21.854653  71.90  98.745  114.20  129.925  188.5
# 1          357.0   78.075406  11.807438  43.79  70.870   78.18   86.100  114.6

# %%
sns.catplot(data=data, y="area_mean", x="diagnosis")
data.groupby("diagnosis")['area_mean'].describe()

## radius variation would mean area variation so already accounted

# data.drop("area_mean", axis=1, inplace=True)
# data.head()
# Out:
#            count        mean         std    min    25%    50%      75%     max
# diagnosis
# 0          212.0  978.376415  367.937978  361.6  705.3  932.0  1203.75  2501.0
# 1          357.0  462.790196  134.287118  143.5  378.2  458.4   551.10   992.1

# %%
sns.catplot(data=data, y="smoothness_mean", x="diagnosis")
data.groupby("diagnosis")['smoothness_mean'].describe()

## 10% difference, sd also same - so not a valid indicator

data.drop("smoothness_mean", axis=1, inplace=True)
data.head()
# Out:
#    diagnosis  radius_mean  perimeter_mean  area_mean  compactness_mean  \
# 0          0        17.99          122.80     1001.0           0.27760
# 1          0        20.57          132.90     1326.0           0.07864
# 2          0        19.69          130.00     1203.0           0.15990
# 3          0        11.42           77.58      386.1           0.28390
# 4          0        20.29          135.10     1297.0           0.13280
#
#    concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  \
# 0          0.3001              0.14710         0.2419                 0.07871
# 1          0.0869              0.07017         0.1812                 0.05667
# 2          0.1974              0.12790         0.2069                 0.05999
# 3          0.2414              0.10520         0.2597                 0.09744
# 4          0.1980              0.10430         0.1809                 0.05883
#
#    radius_se  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
sns.catplot(data=data, y="compactness_mean", x="diagnosis")
data.groupby("diagnosis")['compactness_mean'].describe()

##variation there but depends on perimenter and area - accounted in radius

data.drop("compactness_mean", axis=1, inplace=True)
data.head()
# Out:
#    diagnosis  radius_mean  perimeter_mean  area_mean  concavity_mean  \
# 0          0        17.99          122.80     1001.0          0.3001
# 1          0        20.57          132.90     1326.0          0.0869
# 2          0        19.69          130.00     1203.0          0.1974
# 3          0        11.42           77.58      386.1          0.2414
# 4          0        20.29          135.10     1297.0          0.1980
#
#    concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  \
# 0              0.14710         0.2419                 0.07871     1.0950
# 1              0.07017         0.1812                 0.05667     0.5435
# 2              0.12790         0.2069                 0.05999     0.7456
# 3              0.10520         0.2597                 0.09744     0.4956
# 4              0.10430         0.1809                 0.05883     0.7572
#
#    texture_se  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
sns.catplot(data=data, y="concavity_mean", x="diagnosis")
data.groupby("diagnosis")['concavity_mean'].describe()

## 130% difference
# Out:
#            count      mean       std      min       25%      50%      75%  \
# diagnosis
# 0          212.0  0.160775  0.075019  0.02398  0.109525  0.15135  0.20305
# 1          357.0  0.046058  0.043442  0.00000  0.020310  0.03709  0.05999
#
#               max
# diagnosis
# 0          0.4268
# 1          0.4108

# %%
sns.catplot(data=data, y="concave points_mean", x="diagnosis")
data.groupby("diagnosis")['concave points_mean'].describe()

##variation is there but its related to the prev parameter

data.drop("concave points_mean", axis=1, inplace=True)
data.head()
# Out:
#    diagnosis  radius_mean  perimeter_mean  area_mean  concavity_mean  \
# 0          0        17.99          122.80     1001.0          0.3001
# 1          0        20.57          132.90     1326.0          0.0869
# 2          0        19.69          130.00     1203.0          0.1974
# 3          0        11.42           77.58      386.1          0.2414
# 4          0        20.29          135.10     1297.0          0.1980
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# 0         0.2419                 0.07871     1.0950      0.9053         8.589
# 1         0.1812                 0.05667     0.5435      0.7339         3.398
# 2         0.2069                 0.05999     0.7456      0.7869         4.585
# 3         0.2597                 0.09744     0.4956      1.1560         3.445
# 4         0.1809                 0.05883     0.7572      0.7813         5.438
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
sns.catplot(data=data, y="symmetry_mean", x="diagnosis")
data.groupby("diagnosis")['symmetry_mean'].describe()

## 10% difference and similar deviation

data.drop("symmetry_mean", axis=1, inplace=True)
data.head()
# Out:
#    diagnosis  radius_mean  perimeter_mean  area_mean  concavity_mean  \
# 0          0        17.99          122.80     1001.0          0.3001
# 1          0        20.57          132.90     1326.0          0.0869
# 2          0        19.69          130.00     1203.0          0.1974
# 3          0        11.42           77.58      386.1          0.2414
# 4          0        20.29          135.10     1297.0          0.1980
#
#    fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  ...  \
# 0                 0.07871     1.0950      0.9053         8.589   153.40  ...
# 1                 0.05667     0.5435      0.7339         3.398    74.08  ...
# 2                 0.05999     0.7456      0.7869         4.585    94.03  ...
# 3                 0.09744     0.4956      1.1560         3.445    27.23  ...
# 4                 0.05883     0.7572      0.7813         5.438    94.44  ...
#
#    texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
sns.catplot(data=data, y="fractal_dimension_mean", x="diagnosis")
data.groupby("diagnosis")['fractal_dimension_mean'].describe()

data.drop("fractal_dimension_mean", axis=1, inplace=True)
data.head()
# Out:
#    diagnosis  radius_mean  perimeter_mean  area_mean  concavity_mean  \
# 0          0        17.99          122.80     1001.0          0.3001
# 1          0        20.57          132.90     1326.0          0.0869
# 2          0        19.69          130.00     1203.0          0.1974
# 3          0        11.42           77.58      386.1          0.2414
# 4          0        20.29          135.10     1297.0          0.1980
#
#    radius_se  texture_se  perimeter_se  area_se  smoothness_se  ...  \
# 0     1.0950      0.9053         8.589   153.40       0.006399  ...
# 1     0.5435      0.7339         3.398    74.08       0.005225  ...
# 2     0.7456      0.7869         4.585    94.03       0.006150  ...
# 3     0.4956      1.1560         3.445    27.23       0.009110  ...
# 4     0.7572      0.7813         5.438    94.44       0.011490  ...
#
#    texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0          17.33           184.60      2019.0            0.1622
# ...

# %%
np.size(data)
# Out:
# 14794

# %%
from sklearn.model_selection import train_test_split
import numpy as np

x = data.iloc[:,np.r_[1:5]].values
y = data.iloc[:,0].values

x_train,x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=0)

x_train
# Out:
# array([[1.005e+01, 6.441e+01, 3.108e+02, 2.511e-02],
#        [1.080e+01, 6.879e+01, 3.599e+02, 3.614e-02],
#        [1.614e+01, 1.043e+02, 8.000e+02, 5.500e-02],
#        ...,
#        [9.436e+00, 5.982e+01, 2.786e+02, 2.710e-02],
#        [9.720e+00, 6.073e+01, 2.881e+02, 0.000e+00],
#        [1.151e+01, 7.452e+01, 4.035e+02, 1.112e-01]])

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.fit_transform(x_test)

x_train
# Out:
# array([[-1.15036482, -1.12855021, -0.95876358, -0.80259612],
#        [-0.93798972, -0.94820146, -0.82152548, -0.66066905],
#        [ 0.574121  ,  0.51394098,  0.40858627, -0.41799048],
#        ...,
#        [-1.32422924, -1.31754581, -1.04876494, -0.77699006],
#        [-1.24380987, -1.28007609, -1.02221174, -1.12569574],
#        [-0.73694129, -0.71226578, -0.69966029,  0.30515561]])

# %%
data.__len__()
# Out:
# 569

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier()
rf_clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf_clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.9298245614035088
